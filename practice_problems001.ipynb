# %%
def even_n(num):
    for i in range (num):
        if num%2==0:
            print(num)
            
    return 0


n=[5,2,4,6,23,7,9,13,45,67]
even_n(n)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       6     return 0
#       9 n=[5,2,4,6,23,7,9,13,45,67]
# ---> 10 even_n(n)
#
# Cell In[8], line 2, in even_n(num)
#       1 def even_n(num):
# ----> 2     for i in range (num):
#       3         if num%2==0:
#       4             print(num)
#
# TypeError: 'list' object cannot be interpreted as an integer
