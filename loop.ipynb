# %%
fruits=['a' ,'b','c','d','c']

for i in fruits:
    print(i)
# Out:
# a
# b
# c
# d
# c

# %%
a=0
while(a<5):
    a=a+1
    print("Hello World")
# Out:
# Hello World
# Hello World
# Hello World
# Hello World
# Hello World

# %%
b=0
while(b<5):

   
    if b==1:
        print("good")
    elif b==2:
        print("bad")
    else:
        print("error")    

    b=b+1
# Out:
# error
# good
# bad
# error
# error

# %%
i=0
for i in range(1,6):
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
count= 1
while count <=5:
    print(count)
    count+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
n=5
i=1

for n in range(1,n):
    s=n%2
    if s==0:
        print (n,"is even")
    else:
        print(n,"is odd")
# Out:
# 1 is odd
# 2 is even
# 3 is odd
# 4 is even

# %%
for i in range(5):
    print("enter a number")
    #n=int(input())

# %%
for i in range(5):
    n = 8
    if n > 0:
        print("Positive")
    elif n < 0:
        print("Negative")
    else:
        print("Zero")
# Out:
# Positive
# Positive
# Positive
# Positive
# Positive

# %%
num=[10,3,4,12,45,6,8,9,]

# %%
#for i in num:
n=max(num)
print(n)
# Out:
# 45

# %%
s=25
for i in num:
    if s < i:
        print("good",i)
    else:
        print("bad",i)
# Out:
# bad 10
# bad 3
# bad 4
# bad 12
# good 45
# bad 6
# bad 8
# bad 9

# %%
for i in num:
    if i%3==0:
        print(i,"is divisible by 3")
# Out:
# 3 is divisible by 3
# 12 is divisible by 3
# 45 is divisible by 3
# 6 is divisible by 3
# 9 is divisible by 3

# %%
for i in  num:
    prime=True

    if i<2:
        prime= False

    for a in range(2,i):
        if i%a==0:
            prime= False
            break
    if prime:
        print(i)
# Out:
# 3

# %%
i
