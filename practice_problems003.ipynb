# %%
def num_find(n):
    nums=[1,2,3,4,512,34,56,78,7,8,9]
    #for i in nums:
    if n in nums:
        print("we found The Number")
    else:
        print("not Found")
#a=int(input())
num_find(8)
# Out:
# we found The Number

# %% [markdown]
# Mini Bank System

# %%
def bank():
    global m
    
    if m==0:
        print("Balance is insufficient",m)
        print("Do You want Deposit money ")
        print("Press 1")
        Print("Exit Press 2 ")
        e=int(input())
   
    elif e==1:
           a=int(input())
           m+=a
           print("Balance is",m)
           print("For Withdrawal Press 2")
    elif(e==2):
        print("Thanks")
        return



    elif m>20:
        print("Balance is ",m)
        print ("You can Withdraw money")
